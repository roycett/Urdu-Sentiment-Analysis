# %%
# !pip install gensim
# !pip install LughaatNLP
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.4.0)

# %%
import pandas as pd
import re
from LughaatNLP import LughaatNLP
from gensim.models import KeyedVectors
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Initial Preprocessing with Regex & LughaatNLP

# %%
train = pd.read_csv('/content/drive/MyDrive/imdb_urdu_reviews_train.csv')
val = pd.read_csv('/content/drive/MyDrive/imdb_urdu_reviews_test.csv')

# %%
def clean(text):
  pattern = r'[A-Za-z0-9\W]+'
  return re.sub(pattern,' ',text)

# %%
train_sentences = []
val_sentences = []
preproc = LughaatNLP()

for i in range(len(train)):
  train_sentences.append(preproc.lemmatize_sentence(preproc.remove_stopwords(clean(train['review'][i]))))

for i in range(len(val)):
  val_sentences.append(preproc.lemmatize_sentence(preproc.remove_stopwords(clean(val['review'][i]))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0189035eb6e4> in <cell line: 3>()
#       1 train_sentences = []
#       2 val_sentences = []
# ----> 3 preproc = LughaatNLP()
#       4
#       5 for i in range(len(train)):
#
# NameError: name 'LughaatNLP' is not defined

# %%
train_labels = list(train['sentiment'].map({'positive': 1, 'negative': 0}))
val_labels = list(val['sentiment'].map({'positive': 1, 'negative': 0}))

# %%
df_train = {'text': train_sentences, 'label': train_labels}
df_val = {'text': val_sentences, 'label': val_labels}
df_train = pd.DataFrame(df_train)
df_val = pd.DataFrame(df_val)
df_train.to_csv('train.csv')
df_val.to_csv('val.csv')

# %% [markdown]
# ## Word Embeddings & Secondary Preprocessing

# %%
train = pd.read_csv('/kaggle/input/assignment3-dl-misc/train.csv')
val = pd.read_csv('/kaggle/input/assignment3-dl-misc/val.csv')

train_sentences, val_sentences = list(train['text']), list(val['text'])
train_labels, val_labels = list(train['label']), list(val['label'])

del train
del val

# %%
model = KeyedVectors.load_word2vec_format("/kaggle/input/urdu-word2vec-200dim/urdu_220m_wv_200d.bin", binary=True)
vocab = model.index_to_key
pad_vector = np.zeros(200)

def convert_to_vectors(sentences, model, max_length, pad_vector):
    vectors = []
    for sentence in sentences:
        sentence_vectors = []
        for word in sentence.split():
            try:
                word_vector = model[word]
                sentence_vectors.append(word_vector)
            except KeyError:
                continue
        if len(sentence_vectors) > max_length:
            sentence_vectors = sentence_vectors[:max_length]
        else:
            sentence_vectors += [pad_vector] * (max_length - len(sentence_vectors))
        vectors.append(sentence_vectors)
    return vectors

max_sentence_length = 100

train_vectors = convert_to_vectors(train_sentences, model, max_sentence_length, pad_vector)
val_vectors = convert_to_vectors(val_sentences, model, max_sentence_length, pad_vector)

del train_sentences
del val_sentences

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## LSTM

# %%
import torch.nn.functional as F
class SentimentAnalysisModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(SentimentAnalysisModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc1 = nn.Linear(hidden_dim, 256)
        self.fc2 = nn.Linear(256, 4096)
        self.classifier = nn.Linear(4096, output_dim)

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        x = self.fc1(hidden[-1])
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.classifier(x)
        return x

# %%
input_dim = 200
hidden_dim = 128
output_dim = 2

model = SentimentAnalysisModel(input_dim, hidden_dim, output_dim)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
train_data = TensorDataset(torch.tensor(train_vectors), torch.tensor(train_labels))
val_data = TensorDataset(torch.tensor(val_vectors), torch.tensor(val_labels))

del train_vectors
del val_vectors
del train_labels
del val_labels

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

# %%
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for batch_inputs, batch_labels in train_loader:
        batch_inputs = batch_inputs.to(device, dtype=torch.float)
        batch_labels = batch_labels.to(device)
        optimizer.zero_grad()
        outputs = model(batch_inputs)
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for batch_inputs, batch_labels in val_loader:
            batch_inputs = batch_inputs.to(device, dtype=torch.float)
            batch_labels = batch_labels.to(device)
            outputs = model(batch_inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.tolist())
            all_labels.extend(batch_labels.tolist())

    val_accuracy = accuracy_score(all_labels, all_preds)

    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader):.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1/100, Loss: 0.6932, Validation Accuracy: 0.5155
# Epoch 2/100, Loss: 0.6924, Validation Accuracy: 0.5219
# Epoch 3/100, Loss: 0.6915, Validation Accuracy: 0.5247
# Epoch 4/100, Loss: 0.6903, Validation Accuracy: 0.5246
# Epoch 5/100, Loss: 0.6891, Validation Accuracy: 0.5283
# Epoch 6/100, Loss: 0.6876, Validation Accuracy: 0.5269
# Epoch 7/100, Loss: 0.6859, Validation Accuracy: 0.5254
# Epoch 8/100, Loss: 0.6842, Validation Accuracy: 0.5313
# Epoch 9/100, Loss: 0.6821, Validation Accuracy: 0.5344
# Epoch 10/100, Loss: 0.6800, Validation Accuracy: 0.5359
# Epoch 11/100, Loss: 0.6775, Validation Accuracy: 0.5378
# Epoch 12/100, Loss: 0.6743, Validation Accuracy: 0.5344
# Epoch 13/100, Loss: 0.6706, Validation Accuracy: 0.5386
# Epoch 14/100, Loss: 0.6660, Validation Accuracy: 0.5415
# Epoch 15/100, Loss: 0.6604, Validation Accuracy: 0.5544
# Epoch 16/100, Loss: 0.6533, Validation Accuracy: 0.5472
# Epoch 17/100, Loss: 0.6437, Validation Accuracy: 0.5594
# Epoch 18/100, Loss: 0.6133, Validation Accuracy: 0.5904
# Epoch 19/100, Loss: 0.6185, Validation Accuracy: 0.5340
# Epoch 20/100, Loss: 0.6542, Validation Accuracy: 0.5422
# Epoch 21/100, Loss: 0.6421, Validation Accuracy: 0.5392
# Epoch 22/100, Loss: 0.6312, Validation Accuracy: 0.5469
# Epoch 23/100, Loss: 0.6159, Validation Accuracy: 0.6085
# Epoch 24/100, Loss: 0.5659, Validation Accuracy: 0.6912
# Epoch 25/100, Loss: 0.6128, Validation Accuracy: 0.5383
# Epoch 26/100, Loss: 0.6218, Validation Accuracy: 0.5542
# Epoch 27/100, Loss: 0.5993, Validation Accuracy: 0.5647
# Epoch 28/100, Loss: 0.5675, Validation Accuracy: 0.7013
# Epoch 29/100, Loss: 0.4621, Validation Accuracy: 0.7184
# Epoch 30/100, Loss: 0.4362, Validation Accuracy: 0.7451
# Epoch 31/100, Loss: 0.4106, Validation Accuracy: 0.7463
# Epoch 32/100, Loss: 0.3797, Validation Accuracy: 0.7521
# Epoch 33/100, Loss: 0.3695, Validation Accuracy: 0.7514
# Epoch 34/100, Loss: 0.3384, Validation Accuracy: 0.7421
# Epoch 35/100, Loss: 0.3220, Validation Accuracy: 0.7656
# Epoch 36/100, Loss: 0.3044, Validation Accuracy: 0.7667
# Epoch 37/100, Loss: 0.2867, Validation Accuracy: 0.7503
# Epoch 84/100, Loss: 0.0798, Validation Accuracy: 0.7670
# Epoch 85/100, Loss: 0.0729, Validation Accuracy: 0.7674
# Epoch 86/100, Loss: 0.0781, Validation Accuracy: 0.7651
# Epoch 87/100, Loss: 0.0688, Validation Accuracy: 0.7644
# Epoch 88/100, Loss: 0.0801, Validation Accuracy: 0.7192
# Epoch 89/100, Loss: 0.0742, Validation Accuracy: 0.7678
# Epoch 90/100, Loss: 0.0725, Validation Accuracy: 0.7640
# Epoch 91/100, Loss: 0.0657, Validation Accuracy: 0.7673
# Epoch 92/100, Loss: 0.0731, Validation Accuracy: 0.7625
# Epoch 93/100, Loss: 0.0671, Validation Accuracy: 0.7661
# Epoch 94/100, Loss: 0.0719, Validation Accuracy: 0.7638
# Epoch 95/100, Loss: 0.0867, Validation Accuracy: 0.7585
# Epoch 96/100, Loss: 0.0719, Validation Accuracy: 0.7629
# Epoch 97/100, Loss: 0.0654, Validation Accuracy: 0.7661
# Epoch 98/100, Loss: 0.0636, Validation Accuracy: 0.7657
# Epoch 99/100, Loss: 0.0809, Validation Accuracy: 0.7651
# Epoch 100/100, Loss: 0.0800, Validation Accuracy: 0.7639

# %%
torch.save(model, 'lstm.pth')

# %% [markdown]
# ## BI-LSTM

# %%
import torch.nn.functional as F

class SentimentAnalysisModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(SentimentAnalysisModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, bidirectional=True, batch_first=True)
        self.fc1 = nn.Linear(hidden_dim * 2, 256)
        self.dropout = nn.Dropout(p=0.3)  
        self.classifier = nn.Linear(256, output_dim)

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        
        hidden = torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1)
        
        x = self.fc1(hidden)
        x = F.relu(x)
        x = self.dropout(x)  
        x = self.classifier(x)
        return x

# %%
input_dim = 200
hidden_dim = 64
output_dim = 2

model = SentimentAnalysisModel(input_dim, hidden_dim, output_dim)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %%
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for batch_inputs, batch_labels in train_loader:
        batch_inputs = batch_inputs.to(device, dtype=torch.float)
        batch_labels = batch_labels.to(device)
        optimizer.zero_grad()
        outputs = model(batch_inputs)
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for batch_inputs, batch_labels in val_loader:
            batch_inputs = batch_inputs.to(device, dtype=torch.float)
            batch_labels = batch_labels.to(device)
            outputs = model(batch_inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.tolist())
            all_labels.extend(batch_labels.tolist())

    val_accuracy = accuracy_score(all_labels, all_preds)

    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader):.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1/100, Loss: 0.4245, Validation Accuracy: 0.7925
# Epoch 2/100, Loss: 0.4226, Validation Accuracy: 0.7983
# Epoch 3/100, Loss: 0.4205, Validation Accuracy: 0.7978
# Epoch 4/100, Loss: 0.4189, Validation Accuracy: 0.7985
# Epoch 5/100, Loss: 0.4161, Validation Accuracy: 0.7994
# Epoch 6/100, Loss: 0.4150, Validation Accuracy: 0.8014
# Epoch 7/100, Loss: 0.4131, Validation Accuracy: 0.8009
# Epoch 8/100, Loss: 0.4102, Validation Accuracy: 0.7992
# Epoch 9/100, Loss: 0.4083, Validation Accuracy: 0.8032
# Epoch 56/100, Loss: 0.3343, Validation Accuracy: 0.8131
# Epoch 57/100, Loss: 0.3332, Validation Accuracy: 0.8152
# Epoch 58/100, Loss: 0.3332, Validation Accuracy: 0.8116
# Epoch 59/100, Loss: 0.3301, Validation Accuracy: 0.8112
# Epoch 60/100, Loss: 0.3300, Validation Accuracy: 0.8140
# Epoch 61/100, Loss: 0.3281, Validation Accuracy: 0.7911
# Epoch 62/100, Loss: 0.3256, Validation Accuracy: 0.8109
# Epoch 63/100, Loss: 0.3247, Validation Accuracy: 0.8109
# Epoch 64/100, Loss: 0.3228, Validation Accuracy: 0.8150
# Epoch 65/100, Loss: 0.3230, Validation Accuracy: 0.8124
# Epoch 66/100, Loss: 0.3206, Validation Accuracy: 0.8082
# Epoch 67/100, Loss: 0.3196, Validation Accuracy: 0.8160
# Epoch 68/100, Loss: 0.3174, Validation Accuracy: 0.8146
# Epoch 69/100, Loss: 0.3154, Validation Accuracy: 0.8133
# Epoch 70/100, Loss: 0.3153, Validation Accuracy: 0.8145
# Epoch 71/100, Loss: 0.3133, Validation Accuracy: 0.8131
# Epoch 72/100, Loss: 0.3122, Validation Accuracy: 0.8142
# Epoch 73/100, Loss: 0.3110, Validation Accuracy: 0.8154
# Epoch 74/100, Loss: 0.3085, Validation Accuracy: 0.8117
# Epoch 75/100, Loss: 0.3071, Validation Accuracy: 0.8120
# Epoch 76/100, Loss: 0.3066, Validation Accuracy: 0.8125
# Epoch 77/100, Loss: 0.3045, Validation Accuracy: 0.8108
# Epoch 78/100, Loss: 0.3016, Validation Accuracy: 0.8125
# Epoch 79/100, Loss: 0.3022, Validation Accuracy: 0.8093
# Epoch 80/100, Loss: 0.3010, Validation Accuracy: 0.8097
# Epoch 81/100, Loss: 0.2992, Validation Accuracy: 0.8157
# Epoch 82/100, Loss: 0.2965, Validation Accuracy: 0.8133
# Epoch 83/100, Loss: 0.2961, Validation Accuracy: 0.8126
# Epoch 84/100, Loss: 0.2949, Validation Accuracy: 0.8149
# Epoch 85/100, Loss: 0.2934, Validation Accuracy: 0.8133
# Epoch 86/100, Loss: 0.2899, Validation Accuracy: 0.8174
# Epoch 87/100, Loss: 0.2905, Validation Accuracy: 0.8146
# Epoch 88/100, Loss: 0.2880, Validation Accuracy: 0.8150
# Epoch 89/100, Loss: 0.2871, Validation Accuracy: 0.8163
# Epoch 90/100, Loss: 0.2859, Validation Accuracy: 0.8152
# Epoch 91/100, Loss: 0.2844, Validation Accuracy: 0.8147
# Epoch 92/100, Loss: 0.2827, Validation Accuracy: 0.8158
# Epoch 93/100, Loss: 0.2818, Validation Accuracy: 0.8060
# Epoch 94/100, Loss: 0.2804, Validation Accuracy: 0.8174
# Epoch 95/100, Loss: 0.2785, Validation Accuracy: 0.8133
# Epoch 96/100, Loss: 0.2771, Validation Accuracy: 0.8145
# Epoch 97/100, Loss: 0.2756, Validation Accuracy: 0.8131
# Epoch 98/100, Loss: 0.2732, Validation Accuracy: 0.8155
# Epoch 99/100, Loss: 0.2724, Validation Accuracy: 0.8139
# Epoch 100/100, Loss: 0.2719, Validation Accuracy: 0.8144

# %%
torch.save(model, 'bilstm.pth')
